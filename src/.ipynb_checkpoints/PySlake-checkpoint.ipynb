# %%
import os
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
from scipy import spatial
p_raw = '/project/nsaru/raw/PySlake/'
p_work = '/project/nsaru/work/PySlake/'

# %%
def within(circle,point):
    if np.sqrt(np.dot(circle[0:2]-point,circle[0:2]-point))<circle[2]:
        return True
    else:
        return False

# %%
def nearest_cell(circles,centroids):
    cells_xy = circles[0][:,0:2]
    aggrs_xy = np.array(centroids)
    d = spatial.distance_matrix(cells_xy,aggrs_xy)
    cells_idx = []
    for id in range(d.shape[1]):
        i = np.argmin(d[:,id])
        if within(circles[0][i,:],aggrs_xy[id,:]):
            cells_idx.append(np.array([i,id]))#cell id, aggregate id
        
    return cells_idx

# %%
def cell_ids(circles,cell_labels):
    circles[0][:,0] = np.round(circles[0][:,0],decimals=-2)
    cdf = pd.DataFrame(circles[0][:,0:2], columns=['x', 'y'])
    cdf = cdf.sort_values(by=['x','y'])#counts down by column
    cdf['x'][0:6]=1200
    cdf['x'][6:12]=1400
    cdf['x'][12:18]=1600
    cdf['x'][18:24]=1800
    cdf['x'][24:30]=2000
    cdf['x'][30:36]=2200
    cdf = cdf.sort_values(by=['x','y'])#counts down by column
    cdf['y'][0:6]=np.array([500,700,900,1100,1300,1500])
    cdf['y'][6:12]=np.array([500,700,900,1100,1300,1500])
    cdf['y'][12:18]=np.array([500,700,900,1100,1300,1500])
    cdf['y'][18:24]=np.array([500,700,900,1100,1300,1500])
    cdf['y'][24:30]=np.array([500,700,900,1100,1300,1500])
    cdf['y'][30:36]=np.array([500,700,900,1100,1300,1500])
    cdf = cdf.sort_values(by=['x','y'])#counts down by column
    idx = np.array(cdf.index)
    labels = cell_labels.values[idx,:]
    return idx, cdf,labels

# %%
all_samples = []
all_matches = []
all_areas = []
all_circles = []
all_labels = []
all_times = []
for d in os.listdir(p_raw):
    
    all_samples.append(d)
    t=[]
    labels_t = []
    matches_t = []
    areas_t = []
    circles_t = []
    for f in os.listdir(os.path.join(p_raw,d)):
        if '.csv' in f:
            if f!='ImageInfo.csv':
                cell_labels = pd.read_csv(os.path.join(p_raw,d,f))
    j = 0
    p_img = os.path.join(p_raw,d,'Images')
    if not os.path.isdir(p_img): 
        p_img = os.path.join(p_raw,d,'images')

    for f in os.listdir(p_img):
        t.append(os.path.getctime(os.path.join(p_img,f)))
        img = cv2.imread(os.path.join(p_img,f))
        b,g,r = cv2.split(img)       
        b = cv2.GaussianBlur(b,(3,3),1)   
        ret,bt = cv2.threshold(b,100,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

        h,s,v = cv2.split(cv2.cvtColor(img,cv2.COLOR_BGR2HSV))
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

        ret,thresh = cv2.threshold(v,100,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU) 
 
        circles = cv2.HoughCircles(bt,cv2.HOUGH_GRADIENT,2,210,param1=400,param2=20,minRadius=105,maxRadius=125)

        try:
            if circles.shape[1]<36:
                circles = cv2.HoughCircles(bt,cv2.HOUGH_GRADIENT,2,200,param1=400,param2=10,minRadius=100,maxRadius=120)
            if circles.shape[1]>36:
                circles = cv2.HoughCircles(bt,cv2.HOUGH_GRADIENT,2,200,param1=400,param2=30,minRadius=100,maxRadius=120)
 
            circles = np.uint16(np.around(circles))
            idx,cdf,labels = cell_ids(circles,cell_labels)
            for i in circles[0,:]:
                # draw the outer circle
                cv2.circle(img,(i[0],i[1]),i[2],(0,0,255),5)          
            contours, hierarchy = cv2.findContours(image=thresh, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
            # draw contours on the original image
            cv2.drawContours(image=img, contours=contours, contourIdx=-1, color=(255, 0, 0), thickness=5, lineType=cv2.LINE_AA)
            
            centers = []
            A = []
            for c in contours:
                # compute the center of the contour
                M = cv2.moments(c)
                if M["m00"]>0:
                    cX = int(M["m10"] / M["m00"])
                    cY = int(M["m01"] / M["m00"])
                    centers.append(np.array([cX,cY]))
                    A.append(M["m00"])  
            cells_idx = nearest_cell(circles,centers)
            if circles.shape[1]!=36:
                plt.imshow(img)
                plt.show()                 
            if not os.path.isdir(os.path.join(p_work,d)): os.mkdir(os.path.join(p_work,d))
            fout = os.path.join(p_work,d,f.split('.')[0]+'_labeled.jpg')
            cv2.imwrite(fout,img)

            matches_t.append(cells_idx)
            areas_t.append(A)
            circles_t.append(circles)
            labels_t.append(labels)
            #assign areas to cells using cells_idx
            j = j+1
        except Exception as e:
            print(e)
            print(d+'/'+f)
    all_circles.append(circles_t)
    all_matches.append(matches_t)
    all_areas.append(areas_t)
    all_labels.append(labels_t)
    all_times.append(t)

labels
# Out:
# index 36 is out of bounds for axis 0 with size 36
# Kelly P1_P2_P3_Time2_Depth2/WIN_20230309_14_41_23_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_46_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_56_34_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_56_38_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_58_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_04_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_59_26_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_56_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_00_27_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_04_31_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_01_38_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_05_01_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_59_15_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_18_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_59_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_33_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_37_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_07_14_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_02_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_06_03_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_02_08_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_01_28_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_05_32_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_01_07_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_51_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_09_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_59_04_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_59_00_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_04_21_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_03_30_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_06_54_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_22_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_39_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_02_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_04_11_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_56_47_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_23_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_01_18_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_08_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_02_29_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_28_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_24_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_59_21_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_53_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_07_24_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_04_00_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_56_36_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_10_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_48_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_44_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_00_17_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_02_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_16_03_10_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_47_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_55_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_05_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_57_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time1_Depth2/WIN_20230307_15_58_01_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_46_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_47_04_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_46_54_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_55_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_47_14_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_54_29_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P21_P22_P23_Time2_Depth2/WIN_20230309_16_47_30_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_17_38_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_10_21_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_16_27_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_17_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_12_03_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_58_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_14_05_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_13_14_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_11_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_16_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_16_37_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_09_08_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_10_31_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_17_28_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_14_15_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_13_04_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_07_56_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_06_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_10_41_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_48_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_15_36_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_53_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_13_34_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_10_10_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_16_58_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_15_57_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_17_18_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_10_05_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_12_53_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_27_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_15_46_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_16_07_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_11_12_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_07_35_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_07_51_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_14_35_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_08_22_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_12_33_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_15_26_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_16_17_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_11_02_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_09_03_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_13_54_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_09_24_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_09_45_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P8_P9_P11_Time2_Depth2/WIN_20230309_15_07_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_31_31_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_08_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_11_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_44_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_56_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_27_16_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_36_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_02_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_28_27_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_57_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_20_41_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_29_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_30_09_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_06_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_31_41_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_10_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_48_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_29_29_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_00_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_56_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_47_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_29_49_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_15_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_30_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_39_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_32_01_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_05_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_54_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_27_06_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_29_39_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_58_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_49_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_46_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_52_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_16_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_07_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_28_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_31_51_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_04_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_33_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_22_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_30_30_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_50_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_30_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_25_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_18_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_31_00_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_39_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_28_58_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_51_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_29_18_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_30_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_31_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_03_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_37_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_27_57_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_28_07_Pro.jpg
# loop of ufunc does not support argument 0 of type NoneType which has no callable rint method
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_30_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_45_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_28_48_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_29_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_50_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_31_10_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_53_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_27_37_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_25_23_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_32_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_20_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_11_Pro.jpg
# loop of ufunc does not support argument 0 of type NoneType which has no callable rint method
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_35_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_27_47_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_27_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_28_38_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_26_35_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_55_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_34_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_30_50_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_24_21_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_21_45_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_23_13_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P16_P17_P20_Time2_Depth2/WIN_20230309_16_22_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_50_52_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_52_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_53_55_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_43_11_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_55_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_48_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_34_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_49_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_53_25_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_50_01_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_49_51_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_29_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_26_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_44_53_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_51_12_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_47_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_39_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_40_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_48_09_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_59_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_24_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_03_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_50_42_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_13_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_45_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_53_45_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_49_31_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_51_02_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_57_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_49_20_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_50_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_29_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_50_11_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_53_35_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_49_41_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_50_32_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_44_43_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_09_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_50_21_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_21_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_51_53_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_06_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_49_10_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_52_03_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_23_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_52_24_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_48_50_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_08_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_53_14_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_14_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_54_05_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_54_26_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_54_46_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_51_22_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_49_00_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_52_44_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_45_19_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_31_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_44_48_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_48_30_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_51_43_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_46_16_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_53_04_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_54_15_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_54_36_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_52_13_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_52_34_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_44_38_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_47_18_Pro.jpg
# cannot set using a slice indexer with a different length than the value
# Kelly P13_P14_P15_Time2_Depth2/WIN_20230309_15_48_40_Pro.jpg
# array([[4, 'F', 24, '14.2.2', 12],
#        [6, 'F', 36, '15.2.2', 12],
#        [2, 'C', 9, '13.2.2', 9],
#        [1, 'D', 4, '13.2.2', 4],
#        [2, 'F', 12, '13.2.2', 12],
#        [5, 'C', 27, '15.2.2', 3],
#        [2, 'D', 10, '13.2.2', 10],
#        [1, 'A', 1, '13.2.2', 1],
#        [2, 'B', 8, '13.2.2', 8],
#        [5, 'F', 30, '15.2.2', 6],
#        [3, 'D', 16, '14.2.2', 4],
#        [6, 'C', 33, '15.2.2', 9],
#        [5, 'A', 25, '15.2.2', 1],
#        [1, 'C', 3, '13.2.2', 3],
#        [1, 'F', 6, '13.2.2', 6],
#        [5, 'D', 28, '15.2.2', 4],
#        [1, 'E', 5, '13.2.2', 5],
#        [5, 'E', 29, '15.2.2', 5],
#        [2, 'E', 11, '13.2.2', 11],
#        [4, 'B', 20, '14.2.2', 8],
#        [3, 'C', 15, '14.2.2', 3],
#        [2, 'A', 7, '13.2.2', 7],
#        [4, 'A', 19, '14.2.2', 7],
#        [5, 'B', 26, '15.2.2', 2],
#        [1, 'B', 2, '13.2.2', 2],
#        [3, 'A', 13, '14.2.2', 1],
#        [3, 'B', 14, '14.2.2', 2],
#        [3, 'E', 17, '14.2.2', 5],
#        [3, 'F', 18, '14.2.2', 6],
#        [6, 'A', 31, '15.2.2', 7],
#        [4, 'E', 23, '14.2.2', 11],
#        [6, 'B', 32, '15.2.2', 8],
#        [4, 'D', 22, '14.2.2', 10],
#        [6, 'E', 35, '15.2.2', 11],
#        [6, 'D', 34, '15.2.2', 10],
#        [4, 'C', 21, '14.2.2', 9]], dtype=object)

# %%
os.listdir(p_raw)[0]

# %%
f
